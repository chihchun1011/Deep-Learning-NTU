# %%
pip install stylegan2_pytorch
# Out:
# ...
#      |████████████████████████████████| 92kB 12.6MB/s
# ...
#      |████████████████████████████████| 81kB 10.2MB/s
# ...
#      |████████████████████████████████| 276kB 45.5MB/s
# ...
#      |████████████████████████████████| 71kB 10.9MB/s
# ...
#      |████████████████████████████████| 51kB 8.1MB/s
# ...
#      |████████████████████████████████| 296kB 47.6MB/s
# ...
#      |████████████████████████████████| 153kB 53.1MB/s
# ...
#      |████████████████████████████████| 61kB 10.2MB/s
# ...
#      |████████████████████████████████| 174kB 52.0MB/s
# ...
#      |████████████████████████████████| 71kB 9.9MB/s
# ...
#      |████████████████████████████████| 71kB 10.7MB/s
# ...
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115928 sha256=b448fd545af1dea7b493ebfc0219d728a8730cb6f3870db003a5bb606ea1d734
#   Stored in directory: /root/.cache/pip/wheels/af/19/30/1ea0cad502dcb4e66ed5a690279628c827aea38bbbab75d5ed
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !stylegan2_pytorch \
        --data ./faces \
        --name chih_hw6 \
        --results_dir ./results \
        --models_dir ./models \
        --image-size 64 \
        --num-train-steps 400000 \

# %%
# !cp ./drive/MyDrive/Colab\ Notebooks/model_84.pt ./
# !mkdir ./models
# !mkdir ./models/default
# !mv ./model_84.pt ./models/default/

# %%
# !stylegan2_pytorch --load_from 84 --image-size 64 --num_image_tiles 1 --num_generate 1000 --generate
# Out:
# loading from version 1.8.1
# 100% 1000/1000 [00:23<00:00, 42.92it/s]
# sample images generated at ./results/default/generated-05-14-2021_05-20-46

# %%
# !rm -r output
# !rm -r results
# !mkdir output

# %%
import os

for i in range(1000) :  
  os.rename(f"./results/default/generated-05-14-2021_05-20-46-{i}-ema.jpg", f"./output/{i+1}.jpg")

# %%
# %cd output
# !tar -zcf ../images.tgz *.jpg
# %cd ..
# Out:
# /content/output
# /content

# %%
# !nvidia-smi
# Out:
# Thu May 13 07:47:14 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.19.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   55C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...
